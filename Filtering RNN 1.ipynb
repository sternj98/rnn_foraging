# %%
import numpy as np
from numpy import random as rnd
import scipy.io as sio
from itertools import product
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim

from matplotlib import pyplot as plt
from scipy.stats import zscore

# %%
class Task(object):
    """ 
        Iterable task object
    """
    def __init__(self, max_iter=None, batch_size=1):
        self.max_iter = max_iter
        self.batch_size = batch_size
        self.num_iter = 0

    def __iter__(self):
        return self

    def __next__(self):
        return self.next()

    def next(self):
        if (self.max_iter is None) or (self.num_iter < self.max_iter):
            self.num_iter += 1
            return (self.num_iter - 1) , self.sample()
        else:
            raise StopIteration()

    def sample(self):
        raise NotImplementedError()

# %%
class KalmanFilteringTaskFFWD(Task):
    '''Parameters'''
    def __init__(self, max_iter=None, batch_size=1, n_in=50, n_out=1, stim_dur=10, sigtc_sq=4.0, signu_sq=1.0, gamma=0.1, tr_cond='all_gains'):
        super(KalmanFilteringTaskFFWD, self).__init__(max_iter=max_iter, batch_size=batch_size)
        self.batch_size = batch_size        
        self.n_in       = n_in
        self.n_out      = n_out
        self.stim_dur   = stim_dur
        self.sigtc_sq   = sigtc_sq
        self.signu_sq   = signu_sq
        self.gamma      = gamma # controls how much the hidden state is going to change per timestep
        self.tr_cond    = tr_cond # how reliable is sensory information (not of huge importance to us either)
        self.phi        = np.linspace(-9.0, 9.0, self.n_in) # Phi is the input tuning function

    def sample(self):
        
        NU         = np.sqrt(self.signu_sq) * np.random.randn(self.stim_dur, self.batch_size)
        R          = np.zeros((self.n_in, self.stim_dur, self.batch_size))
        S          = np.zeros((1, self.stim_dur, self.batch_size))
        M          = np.zeros((1, self.stim_dur, self.batch_size))        
        SIG_SQ     = np.zeros((1, self.stim_dur, self.batch_size))
        M_IN       = np.zeros((1, self.stim_dur, self.batch_size))
        SIG_SQ_IN  = np.zeros((1, self.stim_dur, self.batch_size))
        
        A_in       = np.ones((1, self.n_in))
        B_in       = self.phi
        
        if self.tr_cond == 'all_gains':
            G         = (3.0 - 0.3) * np.random.rand(self.stim_dur, self.batch_size) + 0.3
        elif self.tr_cond == 'high_gain': 
            G = np.full((self.stim_dur, self.batch_size),3)
        else:
            G         = np.random.choice([0.3, 3.0],(self.stim_dur, self.batch_size))

        for ii in range(self.batch_size):
            S[0,0,ii]         = np.sqrt(self.signu_sq) * np.random.randn()
            R[:,0,ii]         = G[0,ii] * np.exp(- ((S[0,0,ii] - self.phi) / (np.sqrt(2.0 * self.sigtc_sq))) ** 2)
            R[:,0,ii]         = np.random.poisson(R[:,0,ii])
            M[0,0,ii]         = np.dot(B_in, R[:,0,ii]) / (np.dot(A_in, R[:,0,ii]) + (self.sigtc_sq/self.signu_sq))
            SIG_SQ[0,0,ii]    = 1.0 / ( np.dot(A_in, R[:,0,ii]) / self.sigtc_sq + (1.0 / self.signu_sq))
            M_IN[0,0,ii]      = M[0,0,ii]
            SIG_SQ_IN[0,0,ii] = SIG_SQ[0,0,ii]
            
            for tt in range(1,self.stim_dur):
                # Draw the new mean of the generating process s_t 
                S[0,tt,ii]         = (1.0 - self.gamma) * S[0,tt-1,ii] + NU[tt,ii]
                # Draw new stimulus input through poisson draws w/ rate drawn according to tuning function
                R[:,tt,ii]         = G[tt,ii] * np.exp(- ((S[0,tt,ii] - self.phi) / (np.sqrt(2.0 * self.sigtc_sq))) ** 2)
                R[:,tt,ii]         = np.random.poisson(R[:,tt,ii])
               
                natparam_1_in      = np.dot(B_in, R[:,tt,ii]) / self.sigtc_sq
                natparam_2_in      = np.dot(A_in, R[:,tt,ii]) / self.sigtc_sq
               
                M_IN[0,tt,ii]      = natparam_1_in / natparam_2_in
                SIG_SQ_IN[0,tt,ii] = 1.0 / natparam_2_in
               
                K                  = self.signu_sq + (1.0-self.gamma)**2 * SIG_SQ[0,tt-1,ii]
                       
                M[0,tt,ii]         = ( np.dot(B_in, R[:,tt,ii]) * K + (1.0-self.gamma) * M[0,tt-1,ii] * self.sigtc_sq) / ( np.dot(A_in, R[:,tt,ii]) * K + self.sigtc_sq)
                SIG_SQ[0,tt,ii]    = (self.sigtc_sq * K) / (np.dot(A_in, R[:,tt,ii]) * K + self.sigtc_sq)
            
        example_input         = np.swapaxes(R,0,2)
        example_output        = np.swapaxes(S,0,2)
        opt_s                 = np.swapaxes(M,0,2)

        return torch.from_numpy(example_input).double() , torch.from_numpy(example_output).double(),opt_s

# %%
class RecurrentModel(nn.Module):
    """
        Generalized RNN model from Rylan Schaeffer
    """
    def __init__(self,model_kwargs):
        super(RecurrentModel, self).__init__()
        self.model_kwargs = model_kwargs
        self.input_size = model_kwargs['input_size']
        self.output_size = model_kwargs['output_size']
        self.batch_size = model_kwargs['batch_size']

        # create and save core i.e. the recurrent operation
        self.core = self._create_core(model_kwargs=model_kwargs)

        self.readout = nn.Linear( # linear output layer
            in_features=model_kwargs['core_kwargs']['hidden_size'],
            out_features=self.output_size,
            bias=True)
        
        self.readout_nonlinearity = self._create_readout_nonlinearity(model_kwargs)
        
        param_init_(self) 
        self.reset_core_hidden()

        # converts all weights into doubles i.e. float64
        # this prevents PyTorch from breaking when multiplying float32 * float64
        self.double()

    def _create_core(self, model_kwargs):
        core = nn.RNN(
            input_size=self.input_size,
            batch_first=True,
            **model_kwargs['core_kwargs'])
        return core
    
    def _create_readout_nonlinearity(self,model_kwargs): 
        if model_kwargs['readout_nonlinearity'] == "sigmoid": 
            return torch.sigmoid
        elif model_kwargs['readout_nonlinearity'] == "linear":
            return torch.nn.Identity(self.model_kwargs['core_kwargs']['hidden_size'])
        elif model_kwargs['readout_nonlinearity'] == "elu": 
            return torch.nn.ELU(self.model_kwargs['core_kwargs']['hidden_size'])

    def reset_core_hidden(self):
        self.core_hidden = torch.zeros(self.output_size,self.batch_size,self.model_kwargs['core_kwargs']['hidden_size'],dtype = torch.double)

    def forward(self,x):
        """
        Performs a forward pass through model.

        :param model_input: Tensor with shape (batch size, num step, stimulus dimension)
            
        :return forward_output: dictionary containing 4 keys:
            core_output: Tensor of shape (batch size, num steps, core dimension)
            readout_output: Tensor of shape (batch size, num steps, core dimension)
            readout: Tensor of shape (batch size, num steps, output dimension)
        """ 
        # reset hidden 
        self.reset_core_hidden()
        
        # run trials and get core output
        core_output, new_core_hidden = self.core(x,self.core_hidden)
                
        readout_output = self.readout_nonlinearity(self.readout(core_output))
        
        forward_output = dict(
            core_output = core_output,
            readout_output = readout_output)

        return forward_output

# parameter initialization functions 
def diag_init(tensor: torch.Tensor, offdiag_val : np.float64, diag_val: np.float64) -> torch.Tensor:
    """ 
        Initialize parameters, separating onn and off diag
        In place operation
    """
    shape = tensor.shape
    if len(shape) != 2 or shape[0] != shape[1]:
        raise ValueError('LeInit initializer can only be used for 2D square matrices.')

    off_diag_part = offdiag_val * np.random.randn(shape[0], shape[1])
    tensor = torch.tensor(np.eye(shape[0]) * diag_val + off_diag_part - np.diag(np.diag(off_diag_part)))
    return tensor

def param_init_(recurrent_model):    
    param_init_kwargs = recurrent_model.model_kwargs['param_init_kwargs'] 
#     with torch.no_grad():
    if recurrent_model.model_kwargs['param_init_fn'] == "diag_init_": 
        # Init input-hidden according to Xavier Normal, g = 0.95
        nn.init.xavier_normal_(recurrent_model.core.weight_ih_l0,gain = 0.95).double()
        # Init hidden-hidden according to diag-off-diag decomposition method
        recurrent_model.core.weight_hh_l0 = torch.nn.Parameter(diag_init(recurrent_model.core.weight_hh_l0,param_init_kwargs['offdiag_val'],param_init_kwargs['diag_val'])).double()
        # Init hidden-output according to Xavier Normal, g = 0.95
        nn.init.xavier_normal_(recurrent_model.readout.weight,gain = 0.95).double()

# %%
def peaksort_vis_trial(core_activity : torch.Tensor,normalization = "max",sort_end_ix = None,ax = None): 
    """
        Peaksort visualization of network activity during task
    """ 
    core_activity = core_activity.detach().numpy().T
    core_activity = core_activity[np.any(core_activity!= 0,1),:]
    if sort_end_ix: 
        ix = np.argmax(core_activity[:,:sort_end_ix],1)
    else:
        ix = np.argmax(core_activity,1)
    peaksort = np.argsort(ix)
    if normalization == "max":
        if ax: 
            ax.imshow(np.flipud(core_activity[peaksort,:] / np.max(core_activity,1)[peaksort,np.newaxis]),cmap = 'jet')
        else:
            plt.imshow(np.flipud(core_activity[peaksort,:] / np.max(core_activity,1)[peaksort,np.newaxis]),cmap = 'jet')
    elif normalization == "zscore":
        if ax: 
            ax.imshow(zscore(np.flipud(core_activity[peaksort,:]),axis = 1),cmap = 'jet')
        else:
            plt.imshow(zscore(np.flipud(core_activity[peaksort,:]),axis = 1),cmap = 'jet')

# %%
# ok first figure out what's going on with this task
tr_cond = 'high_gain'
n_iter = 25001
stim_dur = 100
generator = KalmanFilteringTaskFFWD(max_iter=n_iter, batch_size=50, n_in=50, n_out=1, stim_dur=stim_dur, sigtc_sq=4.0, signu_sq=1.0, gamma=0.1, tr_cond=tr_cond)

example_input, example_output, opt_s = generator.sample()
print(example_input.shape)
print(example_output.shape)
print(opt_s.shape)
# Out:
# torch.Size([50, 100, 50])
# torch.Size([50, 100, 1])
# (50, 100, 1)

# %%
# ok, looking cool
trial = 5
fig,ax = plt.subplots(1,2)
ax[0].plot(example_output[trial],label = "Ground Truth (Target)") 
ax[0].plot(opt_s[trial],label = "Optimal inference")
ax[0].legend()
ax[1].imshow(np.flipud(example_input[trial].T))
ax[1].set_title("Stimulus Input")
# Out:
# Text(0.5, 1.0, 'Stimulus Input')

# %%
# define model parameters
n_in = 50
n_out = 1
n_hid =  500
nonlinearity = 'relu'
readout_nonlinearity = 'elu'
model_kwargs = {
                'input_size': n_in, # input: patch_on,patch_off,rew,time_on_patch,time_since_rew
                'output_size': n_out,
                'batch_size': 50,
                'core_kwargs': {
                    'num_layers': 1, 
                    'hidden_size': n_hid,
                    'nonlinearity': nonlinearity},
                'param_init_fn': 'diag_init_',
                'param_init_kwargs': 
                    {
                        'offdiag_val': .2 / np.sqrt(n_hid),
                        'diag_val': .98 
                    },
                'readout_nonlinearity': readout_nonlinearity,
                }

# %%
# Now let's run it through the RNN
trial = 5
model = RecurrentModel(model_kwargs)
model.readout_nonlinearity
output_dict = model.forward(example_input)
plt.figure(figsize = (20,4))
peaksort_vis_trial(output_dict['core_output'][trial])
plt.figure()
plt.plot(output_dict['readout_output'][trial].detach().numpy())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1978-31408cc4bf28> in <module>
#       3 model = RecurrentModel(model_kwargs)
#       4 model.readout_nonlinearity
# ----> 5 output_dict = model.forward(example_input)
#       6 plt.figure(figsize = (20,4))
#       7 peaksort_vis_trial(output_dict['core_output'][trial])
#
# <ipython-input-669-02d9f9b3c799> in forward(self, x)
#      60
#      61         # run trials and get core output
# ---> 62         core_output, new_core_hidden = self.core(x,self.core_hidden)
#      63
#      64         readout_output = self.readout_nonlinearity(self.readout(core_output))
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     228             hx = self.permute_hidden(hx, sorted_indices)
#     229
# --> 230         self.check_forward_args(input, hx, batch_sizes)
#     231         _impl = _rnn_impls[self.mode]
#     232         if batch_sizes is None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     199         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     200
# --> 201         self.check_hidden_size(hidden, expected_hidden_size)
#     202
#     203     def permute_hidden(self, hx: Tensor, permutation: Optional[Tensor]):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/rnn.py in check_hidden_size(self, hx, expected_hidden_size, msg)
#     193                           msg: str = 'Expected hidden size {}, got {}') -> None:
#     194         if hx.size() != expected_hidden_size:
# --> 195             raise RuntimeError(msg.format(expected_hidden_size, tuple(hx.size())))
#     196
#     197     def check_forward_args(self, input: Tensor, hidden: Tensor, batch_sizes: Optional[Tensor]):
#
# RuntimeError: Expected hidden size (1, 120, 500), got (1, 90, 500)

# %%
def gradClamp(parameters, clip=100):
    """
        Element-wise gradient clipping
    """
    for p in parameters:
        p.grad.data.clamp_(-clip,clip)

def binary_crossentropy(x,target,readout_clip = 1e-6): 
    """
        Compute the binary cross-entropy between predictions and targets.
    """
    x = torch.clamp(x,readout_clip,1-readout_clip)
    return - target * torch.log(x) - (1 - target) * torch.log(1 - x)

# %%
# Ready the training
tr_cond = 'high_gain'
n_batches = 200
stim_dur = 100
task = KalmanFilteringTaskFFWD(max_iter=n_batches, batch_size=50, n_in=50, n_out=1, stim_dur=stim_dur, sigtc_sq=4.0, signu_sq=1.0, gamma=0.1, tr_cond=tr_cond)
model_kwargs["batch_size"] = 50
model = RecurrentModel(model_kwargs)

# Training parameters
activity_l2_penalty = 1e-4 
activity_penalty_steps = 5 # number of activity steps before trial end to penalize
param_l2_penalty = 1e-4 # (aka weight decay)
lr = 0.0005
grad_clip = 100
ce_loss = nn.CrossEntropyLoss(reduction = "mean")
mse_loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = lr) # , weight_decay = param_l2_penalty)
total_losses = np.zeros(n_batches)
mse_losses = np.zeros(n_batches)
# Out:
# None

# %%
# TRAINING
s_vec, opt_s_vec, ex_pred_vec, frac_rmse_vec = [], [], [], []
for i, (example_input, example_output, opt_s) in task: # loop over batches in training set 
    optimizer.zero_grad() # zero the gradients
    output_dict = model.forward(example_input) # perform forward pass
    
    opt_vec.append(opt_s)
    net_vec.append(output_dict['readout_output'].detach().numpy())
    
    # calculate loss
    this_mse_loss = torch.sqrt(mse_loss(output_dict['readout_output'][:,:,-1],example_output[:,:,-1]))

    loss = (this_mse_loss).double() # activity_l2_loss 
    loss.backward() # backpropagate gradients
#     print(len(torch.where(model.core.weight_hh_l0.grad != 0)[0]))
    gradClamp(model.parameters(), clip = grad_clip) # clip gradients 
    optimizer.step() # perform optimization step
    
    total_losses[i] = loss.item() 
    mse_losses[i] = this_mse_loss.item()
    
    s_vec.append(example_output[:,:,-1].detach().numpy())
    opt_s_vec.append(opt_s[:,:,-1])
    ex_pred_vec.append(output_dict['readout_output'].detach().numpy()[:,:,-1])

    if i % 5 == 0:
        rmse_opt  = np.sqrt(np.nanmean((np.asarray(s_vec) - np.asarray(opt_s_vec))**2))
        rmse_net  = np.sqrt(np.nanmean((np.asarray(s_vec) - np.squeeze(np.asarray(ex_pred_vec)))**2))
        frac_rmse = (rmse_net - rmse_opt) / rmse_opt
        frac_rmse_vec.append(frac_rmse)
        print('Batch #%d; Frac. RMSE: %.6f; Opt. RMSE: %.6f; Net. RMSE: %.6f' % (i, frac_rmse, rmse_opt, rmse_net))
        s_vec       = []
        opt_s_vec   = []
        ex_pred_vec = []
# Out:
# Batch #0; Frac. RMSE: 23.109343; Opt. RMSE: 0.313637; Net. RMSE: 7.561591
# Batch #5; Frac. RMSE: 115403.520560; Opt. RMSE: 0.312916; Net. RMSE: 36111.922437
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1558-92a6c3b3b5f6> in <module>
#       1 # TRAINING
#       2 s_vec, opt_s_vec, ex_pred_vec, frac_rmse_vec = [], [], [], []
# ----> 3 for i, (example_input, example_output, opt_s) in task: # loop over batches in training set
#       4     optimizer.zero_grad() # zero the gradients
#       5     output_dict = model.forward(example_input) # perform forward pass
#
# <ipython-input-493-509932d7ef9a> in __next__(self)
#      12
#      13     def __next__(self):
# ---> 14         return self.next()
#      15
#      16     def next(self):
#
# <ipython-input-493-509932d7ef9a> in next(self)
#      17         if (self.max_iter is None) or (self.num_iter < self.max_iter):
#      18             self.num_iter += 1
# ---> 19             return (self.num_iter - 1) , self.sample()
#      20         else:
#      21             raise StopIteration()
#
# <ipython-input-494-200b1a13a435> in sample(self)
#      47                 # Draw new stimulus input through poisson draws w/ rate drawn according to tuning function
#      48                 R[:,tt,ii]         = G[tt,ii] * np.exp(- ((S[0,tt,ii] - self.phi) / (np.sqrt(2.0 * self.sigtc_sq))) ** 2)
# ---> 49                 R[:,tt,ii]         = np.random.poisson(R[:,tt,ii])
#      50
#      51                 natparam_1_in      = np.dot(B_in, R[:,tt,ii]) / self.sigtc_sq
#
# mtrand.pyx in numpy.random.mtrand.RandomState.poisson()
#
# _common.pyx in numpy.random._common.disc()
#
# _common.pyx in numpy.random._common.discrete_broadcast_d()
#
# _common.pyx in numpy.random._common.check_array_constraint()
#
# <__array_function__ internals> in all(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py in all(a, axis, out, keepdims)
#    2396
#    2397     """
# -> 2398     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#    2399
#    2400
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:

# %%
trial = 0
t_len = len(output_dict['readout_output'][trial,:,-1])
n_neurons = output_dict['core_output'][trial].shape[0]
fig,ax = plt.subplots(2,1)
ax[0].plot(output_dict['readout_output'][trial,:,-1].detach().numpy())
ax[0].plot(opt_s[0,:,-1])
ax[0].plot(example_output[0,:,-1])

# ax[1].imshow(np.flipud(example_input[trial].detach().numpy().T))
peaksort_vis_trial(output_dict['core_output'][trial],ax = ax[1])
aspect = 3.5 * t_len/n_neurons
forceAspect(ax[1],aspect)
# forceAspect(ax[0],aspect)

# %% [markdown]
# ## Now create task for Point Process Filtering
#
# We take the setting of a point process. Let the reward events $0 < u_1 < u_2 < ... < u_L$ be a realization from a point process with conditional intensity function $\lambda(u | H_u)$ where $u$ is a continuous-valued non-negative variable that denotes continuous time. N.B. we will use $t$ to denote a discrete time index. Let $N(u)$ be the associated counting process.
#
# By definition of the CIF:
#
# $$P(N(u + \Delta) - N(u) = 1 | H_u ) \approx \lambda(u|H_u)\Delta + o(\Delta)  $$
#
# s.t. with small enough discretization $\Delta$, $y_t \in \{0,1\}$
#
# $$p(y_t | H_t) = (\lambda(t | H_t)\Delta)^y e^{-\lambda (t|H_t)\Delta}   $$
#
#
# Then let $\lambda(t | \theta_t,H_t) = e^{\theta_t}$
# We adopt a SRW on the dynamics of $\theta_t$ s.t. $\theta_t = \theta_{t-1} + \epsilon_{t}$ where $\epsilon_t \sim N(0,\sigma_\epsilon^2)$. This yields $\sigma_{t|t-1}^2 = \sigma_{t-1|t-1}^2 + \sigma_{\epsilon}^2 $
#
# Solving the filtering equation, we arrive at:
#
# $$\theta_{t|t} = \theta_{t | t-1} + \sigma_{t|t}^2 (y_t - e^{\theta_{t|t-1}}\Delta ) = \theta_{t | t-1} + \sigma_{t|t}^2 (y_t - \lambda(t | \theta_{t},H_t)\Delta ) $$
#
# $$\sigma_{t|t}^2 = \left(\lambda(t | \theta_{t-1},H_t)\Delta + \frac{1}{\sigma_{t|t-1}^2}   \right)^{-1} $$
#
# We will initialize $\theta_{0|0}$ and $\sigma^2_{0|0}$ according to some prior distribution.

# %%
# Event stream generating functions
def stream_from_events(event_times,end_t,dt = 0.05): 
    """ 
        Convert event times into a binary stream of continuous data
    """ 
    rew_ix = np.round(event_times / dt).astype(int)
    rew_stream = np.zeros(int(np.round(end_t / dt)))
    rew_stream[rew_ix] = 1
    return rew_stream

def stream_from_sized_events(event_times,event_sizes,end_t,dt = 0.05): 
    """
        Approximate rewards of varying sizes by using multiple positive events in a row
    """
    rew_ix = np.round(event_times / dt).astype(int)
    rew_stream = np.zeros(int(np.round(end_t / dt)))
    for ix,dur in zip(rew_ix,event_sizes):
        rew_stream[ix:ix+dur] = 1
    return rew_stream

# Foraging session point process generation functions
def discrete_expo_pdf(N0,n_rew_locs = 20,tau = .125):
    """
        Assign reward delivery probabilities according to scaled Expo decay
    """
    x = np.arange(n_rew_locs)
    cdf = 1 - N0 * np.exp(-tau * x) / tau + N0 / tau
    pdf = cdf[1:] - cdf[:-1]
    return np.insert(pdf,0,1.) # add a deterministic reward at t = 0

def generate_session_y(rewsizes,N0s,n_trials_per_tt,end_t = 20,dt = 0.05): 
    """
        Arguments: list of reward sizes and N0 values and # trials per trial type
        Returns: y_tts_trials: dictionary with trial type keys and n_trials_per_tt streams of reward
            - y generated with stream_from_sized_events
    """
    # make PDFs
    pdfs_dict = {}
    for this_n0 in N0s: 
        pdfs_dict[this_n0] = discrete_expo_pdf(this_n0,n_rew_locs = end_t)
    
    # make trial reward streams
    y_tts_trials = {}
    tts = list(product(*[rewsizes,N0s]))
    for (this_rewsize,this_n0) in tts: 
        y_tts_trials[(this_rewsize,this_n0)] = np.empty_like([n_trials_per_tt],shape = (n_trials_per_tt,int(round(end_t/dt))))
        for i_trial in range(n_trials_per_tt): 
            trial_rewtimes = np.where(rnd.random(end_t) - pdfs_dict[this_n0] < 0)[0]
            y_trial = stream_from_sized_events(trial_rewtimes,np.full(len(trial_rewtimes),this_rewsize),end_t,dt)
            y_tts_trials[(this_rewsize,this_n0)][i_trial,:] = y_trial
    return y_tts_trials

def generate_from_rewtimes_y(rewsizes,rewseqs,n_trials_per_tt,end_t = 20,dt = 0.05): 
    """ 
        Arguments: dict of reward sizes,subplist of  reward time sequences 
        Returns: y_tts_trials: list of y reward streams generated from stream_from_sized_events
    """
    y_tts_trials = {}
    tts = list(product(rewsizes,np.arange(len(rewseqs),dtype = int)))
    for (this_rewsize,i_rewseq) in tts: 
        y_tts_trials[(this_rewsize,i_rewseq)] = np.tile(stream_from_sized_events(rewseqs[i_rewseq],np.full(len(rewseqs[i_rewseq]),this_rewsize),end_t,dt),(n_trials_per_tt,1))
    return y_tts_trials

# %%
class PPSSM_FilteringTask(Task):
    """ 
        Filter point process to return estimated lambda 
        
        Use foraging session function to create the generative point process (S)
    """
    def __init__(self,ppssm_params,max_iter=100, n_in=50,sigtc_sq=.02,tr_cond='high_gain'):
        super(PPSSM_FilteringTask, self).__init__(ppssm_params)
        self.n_in       = n_in
        self.ppssm_params = ppssm_params
        self.max_iter = max_iter
        self.y_generator, self.stim_dur, self.batch_size = self._create_PPSSM_generating_fn()
        
        self.tr_cond    = tr_cond # how reliable is sensory information
        # Phi is the input tuning function
        self.phi        = np.linspace(0, 1, self.n_in) # For some reward cells and some no-reward cells
#         self.phi        = np.ones(self.n_in) # Input only to reward
        self.dt = self.ppssm_params['generation_params']['dt']
        self.sigtc_sq = sigtc_sq
    
    def _create_PPSSM_generating_fn(self):
        gen_fn_params = self.ppssm_params["generation_params"]
        if self.ppssm_params["generation_fn"] == "stochastic_foraging_session": 
            y_generator = generate_session_y 
            n_tts = len(list(product(*[gen_fn_params['rewsizes'],gen_fn_params['N0s']])))
            stim_dur = int(np.round(gen_fn_params['end_t'] / gen_fn_params['dt']))
            batch_size = int(gen_fn_params['n_trials_per_tt'] * n_tts)
        elif self.ppssm_params["generation_fn"] == "rewtimes_foraging_session": 
            y_generator = generate_from_rewtimes_y
            n_tts = len(list(product(*[gen_fn_params['rewsizes'],gen_fn_params['rewseqs']])))
            stim_dur = int(np.round(gen_fn_params['end_t'] / gen_fn_params['dt'])) 
            batch_size = int(gen_fn_params['n_trials_per_tt'] * n_tts)
        elif self.ppssm_params["generation_fn"] == "srw_point_process": 
            y_generator = srw_point_process 
            stim_dur = int(np.round(gen_fn_params['end_t'] / gen_fn_params['dt']))  
            batch_size = gen_fn_params['n_trials']
        return y_generator,stim_dur,batch_size
        
    def sample(self):
        # Set trial stimulus gains
        if self.tr_cond == 'all_gains':
            G         = (3.0 - 0.3) * np.random.rand(self.stim_dur, self.batch_size) + 0.3
        elif self.tr_cond == 'high_gain': 
            G         = np.full((self.stim_dur, self.batch_size),3)
        else:
            G         = np.random.choice([0.3, 3.0],(self.stim_dur, self.batch_size))
            
        # make session and flatten it to get training batch
        y_dict     = self.y_generator(**self.ppssm_params['generation_params'])
        if type(y_dict) == dict: # for the session generation functions
            S          = np.concatenate([y_dict[i] for i in y_dict.keys()]).T[np.newaxis,:,:]
        else: 
            S = y_dict[0].T[np.newaxis,:,:]
        self.sigma2_eps  = np.var(S) 
        # initialize input neuron response tensor
        R          = np.zeros((self.n_in, self.stim_dur, self.batch_size))
        
        # Initialize parameters for optimal filtering from sensory input
        M          = np.zeros((1, self.stim_dur, self.batch_size))        
        SIG_SQ     = np.zeros((1, self.stim_dur, self.batch_size))

        ones    = np.ones((1, self.n_in))
        
        for ii in range(self.batch_size): # iterate over trials
            # initialize filtering stuff for this trial
            R[:,0,ii]         = G[0,ii] * np.exp(- ((S[0,0,ii] - self.phi) / (np.sqrt(2.0 * self.sigtc_sq))) ** 2)
            R[:,0,ii]         = np.random.poisson(R[:,0,ii])
            M[0,0,ii]         = np.dot(self.phi, R[:,0,ii]) / np.dot(ones,self.phi)
            SIG_SQ[0,0,ii]    = 1 # initialize to relatively high volatility self.sigma2_eps
            
            for tt in range(1,self.stim_dur): # iterate over timesteps
                # Draw new stimulus input through poisson draws w/ rate drawn according to tuning function
                R[:,tt,ii]         = G[tt,ii] * np.exp(- ((S[0,tt,ii] - self.phi) / (np.sqrt(2.0 * self.sigtc_sq))) ** 2)
                R[:,tt,ii]         = rnd.poisson(R[:,tt,ii])
               
                y_obs = np.dot(self.phi, R[:,tt,ii]) / (np.dot(ones,self.phi) * G[tt,ii])
                sigma2_given_tminus1 = SIG_SQ[0,tt-1,ii] + self.sigma2_eps
                SIG_SQ[0,tt,ii] = 1 / (dt * np.exp(M[0,tt-1,ii]) + 1 / sigma2_given_tminus1)
                M[0,tt,ii] = M[0,tt-1,ii] + SIG_SQ[0,tt,ii] * (y_obs - self.dt * np.exp(M[0,tt-1,ii]))

        example_input         = np.swapaxes(R,0,2) # this will be the poisson drawn input 
        example_output        = np.swapaxes(S,0,2) # this will be the stream of reward events (ground truth)
        opt_s                 = np.swapaxes(M,0,2) # this will be output of PPSSM call

        return torch.from_numpy(example_input).double() , torch.from_numpy(example_output).double(),opt_s

# %%
# define PPSSM parameters 
ppssm_params = {"generation_fn": "stochastic_foraging_session", # stochastic or defined by reward times
                "generation_params":
                           {"rewsizes":[4],
                           "N0s":[.5],
                           "n_trials_per_tt": 20,
                           "dt": 0.050,
                           "end_t" : 5}
                            }

# %%
task = PPSSM_FilteringTask(ppssm_params = stochastic_ppssm_params,max_iter = 100)
example_input,example_output,opt_s = task.sample() 
plt.imshow(np.flipud(example_input[12].detach().numpy().T))
plt.figure()
plt.plot(example_output[12].detach().numpy())
plt.figure() 
plt.plot(np.exp(opt_s[80]))

# %%
# ppssm_params = {"generation_fn": "stochastic_foraging_session", # stochastic or defined by reward times
#                 "generation_params":
#                            {"rewsizes":[4],
#                            "N0s":[.5],
#                            "n_trials_per_tt": 20,
#                            "dt": 0.050,
#                            "end_t" : 5}
#                             }

rxx = [np.array([0]),np.array([0,1]),np.array([0,2]),np.array([0,1,2])]
ppssm_params = {"generation_fn": "rewtimes_foraging_session", # stochastic or defined by reward times
                "generation_params":
                           {"rewsizes":[4],
                           "rewseqs": rxx,
                           "n_trials_per_tt": 1,
                           "dt": 0.050,
                           "end_t" : 5}
                            }

# %%
def forceAspect(ax,aspect):
    im = ax.get_images()
    extent =  im[0].get_extent()
    ax.set_aspect(abs((extent[1]-extent[0])/(extent[3]-extent[2]))/aspect)

    
task = PPSSM_FilteringTask(ppssm_params = rxx_ppssm_params)
example_input,example_output,opt_s = task.sample() 

trial = 0
model_kwargs['batch_size'] = task.batch_size
model_kwargs['readout_nonlinearity'] = 'linear'
model = RecurrentModel(model_kwargs)
output_dict = model.forward(example_input)

plt.figure()
plt.plot(output_dict['readout_output'][trial].detach().numpy())
plt.plot(opt_s[trial])
# plt.plot(example_output[trial].detach().numpy() )
fig,ax = plt.subplots(2,1)
ax[0].imshow(np.flipud(example_input[trial].detach().numpy().T))
ax[0].set_title("Input")
peaksort_vis_trial(output_dict['core_output'][trial],sort_end_ix = 20,ax = ax[1])
aspect = example_input[trial].shape[0]/example_input[trial].shape[1]
ax[1].set_title("Hidden Activity")
forceAspect(ax[1],aspect)
fig.tight_layout()

# %%
# define model parameters
n_in = 50
n_out = 1
n_hid =  500
nonlinearity = 'relu'
readout_nonlinearity = 'linear'
model_kwargs = {
                'input_size': n_in, # input: patch_on,patch_off,rew,time_on_patch,time_since_rew
                'output_size': n_out,
                'batch_size': 50,
                'core_kwargs': {
                    'num_layers': 1, 
                    'hidden_size': n_hid,
                    'nonlinearity': nonlinearity},
                'param_init_fn': 'diag_init_',
                'param_init_kwargs': 
                    {
                        'offdiag_val': .2 / np.sqrt(n_hid),
                        'diag_val': .98 
                    },
                'readout_nonlinearity': readout_nonlinearity,
                'connectivity_kwargs': { 
                    'input_mask': 'none',
                    'recurrent_mask': 'none',
                    'readout_mask': 'none',
                                        },
                }

stochastic_ppssm_params = {"generation_fn": "stochastic_foraging_session", # stochastic or defined by reward times
                "generation_params":
                           {"rewsizes":[1,2,4],
                           "N0s":[.125,.25,.5],
                           "n_trials_per_tt": 10,
                           "dt": 0.050,
                           "end_t" : 5}
                            }

rxx_ppssm_params = {"generation_fn": "rewtimes_foraging_session", # stochastic or defined by reward times
                "generation_params":
                           {"rewsizes":[2,4],
                           "rewseqs": rxx,
                           "n_trials_per_tt": 15,
                           "dt": 0.050,
                           "end_t" : 5}
                            }

srw_ppssm_params = {"generation_fn": "srw_point_process", # stochastic or defined by reward times
                "generation_params":
                           {
                               "end_t" : 2,
                               "theta0" : 2, 
                               "sigma2_eps" : .05,
                               "n_trials": 10,
                               "dt": 0.050,}
                            }

# %%
# Training setup
tr_cond = 'high_gain'
n_batches = 501
task = PPSSM_FilteringTask(stochastic_ppssm_params,max_iter = n_batches)
print(task.max_iter)
model_kwargs['batch_size'] = task.batch_size
model = RecurrentModel(model_kwargs)

# Training parameters
activity_l2_penalty = 1e-4 
activity_penalty_steps = 5 # number of activity steps before trial end to penalize
param_l2_penalty = 1e-4 # (aka weight decay)
lr = 0.0005
grad_clip = 10
mse_loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = lr,weight_decay = param_l2_penalty)
total_losses = np.zeros(n_batches)
mse_losses = np.zeros(n_batches)
# Out:
# 501

# %%
# TRAINING
s_vec, opt_s_vec, ex_pred_vec, frac_rmse_vec = [], [], [], []
for i, (example_input, example_output, opt_s) in task: # loop over batches in training set 
    optimizer.zero_grad() # zero the gradients
    output_dict = model.forward(example_input) # perform forward pass
    
    # calculate loss
    this_mse_loss = torch.sqrt(mse_loss(output_dict['readout_output'][:,:,-1],torch.from_numpy(opt_s)[:,:,-1])) # example_output[:,:,-1]))
#     this_mse_loss = torch.sqrt(mse_loss(output_dict['readout_output'][:,:,-1],example_output[:,:,-1])) # example_output[:,:,-1]))

    loss = (this_mse_loss).double()
    loss.backward() # backpropagate gradients
    gradClamp(model.parameters(), clip = grad_clip) # clip gradients 
    optimizer.step() # perform optimization step
    
    total_losses[i] = loss.item() 
    mse_losses[i] = this_mse_loss.item()
    
    s_vec.append(example_output[:,:,-1].detach().numpy())
    opt_s_vec.append(opt_s[:,:,-1])
    ex_pred_vec.append(output_dict['readout_output'].detach().numpy()[:,:,-1])
    
    if i % 5 == 0:
        rmse_opt  = np.sqrt(np.nanmean((np.asarray(s_vec) - np.asarray(opt_s_vec))**2))
        rmse_net  = np.sqrt(np.nanmean((np.asarray(s_vec) - np.squeeze(np.asarray(ex_pred_vec)))**2))
        frac_rmse = (rmse_net - rmse_opt) / rmse_opt
        frac_rmse_vec.append(frac_rmse)
        print('Batch #%d; filtering RMSE: %.3f;Frac. RMSE: %.6f; Opt. RMSE: %.6f; Net. RMSE: %.6f' % (i, np.mean(mse_losses[i-5:i]),frac_rmse, rmse_opt, rmse_net))
#         print('Batch #%d; RMSE: %.6f' % (i, this_mse_loss))
        s_vec       = []
        opt_s_vec   = []
        ex_pred_vec = []
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Batch #0; filtering RMSE: nan;Frac. RMSE: 80813.064587; Opt. RMSE: 0.373050; Net. RMSE: 30147.664465
# Batch #5; filtering RMSE: 101810.368;Frac. RMSE: 453861.575367; Opt. RMSE: 0.372362; Net. RMSE: 169001.219255
# Batch #10; filtering RMSE: 6767.654;Frac. RMSE: 13838.158079; Opt. RMSE: 0.373903; Net. RMSE: 5174.496184
# Batch #15; filtering RMSE: 572.547;Frac. RMSE: 2332.985556; Opt. RMSE: 0.372423; Net. RMSE: 869.230586
# Batch #20; filtering RMSE: 461.799;Frac. RMSE: 924.182180; Opt. RMSE: 0.371206; Net. RMSE: 343.433515
# Batch #25; filtering RMSE: 57.042;Frac. RMSE: 151.969416; Opt. RMSE: 0.365815; Net. RMSE: 55.958554
# Batch #30; filtering RMSE: 38.141;Frac. RMSE: 121.598424; Opt. RMSE: 0.369392; Net. RMSE: 45.286933
# Batch #35; filtering RMSE: 71.167;Frac. RMSE: 268.617998; Opt. RMSE: 0.364867; Net. RMSE: 98.374821
# Batch #40; filtering RMSE: 56.071;Frac. RMSE: 109.088583; Opt. RMSE: 0.371038; Net. RMSE: 40.847065
# Batch #45; filtering RMSE: 9.144;Frac. RMSE: 24.052218; Opt. RMSE: 0.369673; Net. RMSE: 9.261125
# Batch #50; filtering RMSE: 5.423;Frac. RMSE: 14.975557; Opt. RMSE: 0.368108; Net. RMSE: 5.880736
# Batch #55; filtering RMSE: 4.845;Frac. RMSE: 10.181041; Opt. RMSE: 0.368245; Net. RMSE: 4.117360
# Batch #60; filtering RMSE: 4.959;Frac. RMSE: 13.935665; Opt. RMSE: 0.371402; Net. RMSE: 5.547135
# Batch #65; filtering RMSE: 3.845;Frac. RMSE: 9.076564; Opt. RMSE: 0.369621; Net. RMSE: 3.724509
# Batch #70; filtering RMSE: 2.091;Frac. RMSE: 4.491805; Opt. RMSE: 0.368282; Net. RMSE: 2.022533
# Batch #75; filtering RMSE: 1.783;Frac. RMSE: 5.139957; Opt. RMSE: 0.370332; Net. RMSE: 2.273821
# Batch #80; filtering RMSE: 2.651;Frac. RMSE: 5.756074; Opt. RMSE: 0.366751; Net. RMSE: 2.477795
# Batch #85; filtering RMSE: 2.027;Frac. RMSE: 4.966082; Opt. RMSE: 0.373272; Net. RMSE: 2.226970
# Batch #90; filtering RMSE: 1.538;Frac. RMSE: 3.134884; Opt. RMSE: 0.372353; Net. RMSE: 1.539636
# Batch #95; filtering RMSE: 0.901;Frac. RMSE: 1.403675; Opt. RMSE: 0.368989; Net. RMSE: 0.886930
# Batch #100; filtering RMSE: 0.731;Frac. RMSE: 1.083465; Opt. RMSE: 0.372249; Net. RMSE: 0.775568
# Batch #105; filtering RMSE: 0.667;Frac. RMSE: 0.905332; Opt. RMSE: 0.370232; Net. RMSE: 0.705415
# Batch #110; filtering RMSE: 0.600;Frac. RMSE: 0.754230; Opt. RMSE: 0.367325; Net. RMSE: 0.644372
# Batch #115; filtering RMSE: 0.632;Frac. RMSE: 1.038808; Opt. RMSE: 0.371083; Net. RMSE: 0.756568
# Batch #120; filtering RMSE: 0.649;Frac. RMSE: 0.741535; Opt. RMSE: 0.374885; Net. RMSE: 0.652875
# Batch #125; filtering RMSE: 0.524;Frac. RMSE: 0.574063; Opt. RMSE: 0.369249; Net. RMSE: 0.581222
# Batch #130; filtering RMSE: 0.485;Frac. RMSE: 0.564566; Opt. RMSE: 0.370857; Net. RMSE: 0.580231
# Batch #135; filtering RMSE: 0.466;Frac. RMSE: 0.558917; Opt. RMSE: 0.366158; Net. RMSE: 0.570810
# Batch #140; filtering RMSE: 0.506;Frac. RMSE: 0.583693; Opt. RMSE: 0.371055; Net. RMSE: 0.587637
# Batch #145; filtering RMSE: 0.555;Frac. RMSE: 0.761494; Opt. RMSE: 0.372560; Net. RMSE: 0.656262
# Batch #150; filtering RMSE: 0.466;Frac. RMSE: 0.521557; Opt. RMSE: 0.369040; Net. RMSE: 0.561515
# Batch #155; filtering RMSE: 0.487;Frac. RMSE: 0.564402; Opt. RMSE: 0.369927; Net. RMSE: 0.578715
# Batch #160; filtering RMSE: 0.440;Frac. RMSE: 0.475958; Opt. RMSE: 0.370431; Net. RMSE: 0.546741
# Batch #165; filtering RMSE: 0.410;Frac. RMSE: 0.441673; Opt. RMSE: 0.369544; Net. RMSE: 0.532761
# Batch #170; filtering RMSE: 0.386;Frac. RMSE: 0.369384; Opt. RMSE: 0.368794; Net. RMSE: 0.505020
# Batch #175; filtering RMSE: 0.385;Frac. RMSE: 0.379642; Opt. RMSE: 0.375090; Net. RMSE: 0.517490
# Batch #180; filtering RMSE: 0.376;Frac. RMSE: 0.418474; Opt. RMSE: 0.371703; Net. RMSE: 0.527251
# Batch #185; filtering RMSE: 0.367;Frac. RMSE: 0.329108; Opt. RMSE: 0.368962; Net. RMSE: 0.490390
# Batch #190; filtering RMSE: 0.344;Frac. RMSE: 0.297566; Opt. RMSE: 0.371285; Net. RMSE: 0.481767
# Batch #195; filtering RMSE: 0.326;Frac. RMSE: 0.259791; Opt. RMSE: 0.369267; Net. RMSE: 0.465199
# Batch #200; filtering RMSE: 0.333;Frac. RMSE: 0.255886; Opt. RMSE: 0.369269; Net. RMSE: 0.463759
# Batch #205; filtering RMSE: 0.312;Frac. RMSE: 0.262635; Opt. RMSE: 0.369065; Net. RMSE: 0.465994
# Batch #210; filtering RMSE: 0.296;Frac. RMSE: 0.187780; Opt. RMSE: 0.371172; Net. RMSE: 0.440871
# Batch #215; filtering RMSE: 0.299;Frac. RMSE: 0.210128; Opt. RMSE: 0.371904; Net. RMSE: 0.450051
# Batch #220; filtering RMSE: 0.287;Frac. RMSE: 0.228990; Opt. RMSE: 0.368098; Net. RMSE: 0.452389
# Batch #225; filtering RMSE: 0.293;Frac. RMSE: 0.207931; Opt. RMSE: 0.372120; Net. RMSE: 0.449495
# Batch #230; filtering RMSE: 0.297;Frac. RMSE: 0.193508; Opt. RMSE: 0.368243; Net. RMSE: 0.439501
# Batch #235; filtering RMSE: 0.300;Frac. RMSE: 0.263086; Opt. RMSE: 0.367259; Net. RMSE: 0.463880
# Batch #240; filtering RMSE: 0.306;Frac. RMSE: 0.221817; Opt. RMSE: 0.367736; Net. RMSE: 0.449306
# Batch #245; filtering RMSE: 0.300;Frac. RMSE: 0.212146; Opt. RMSE: 0.369329; Net. RMSE: 0.447681
# Batch #250; filtering RMSE: 0.283;Frac. RMSE: 0.145819; Opt. RMSE: 0.370870; Net. RMSE: 0.424950
# Batch #255; filtering RMSE: 0.258;Frac. RMSE: 0.119043; Opt. RMSE: 0.374310; Net. RMSE: 0.418868
# Batch #260; filtering RMSE: 0.261;Frac. RMSE: 0.186970; Opt. RMSE: 0.370059; Net. RMSE: 0.439249
# Batch #265; filtering RMSE: 0.263;Frac. RMSE: 0.143266; Opt. RMSE: 0.370063; Net. RMSE: 0.423081
# Batch #270; filtering RMSE: 0.258;Frac. RMSE: 0.196133; Opt. RMSE: 0.372236; Net. RMSE: 0.445244
# Batch #275; filtering RMSE: 0.259;Frac. RMSE: 0.139835; Opt. RMSE: 0.371995; Net. RMSE: 0.424013
# Batch #280; filtering RMSE: 0.256;Frac. RMSE: 0.145814; Opt. RMSE: 0.372014; Net. RMSE: 0.426259
# Batch #285; filtering RMSE: 0.259;Frac. RMSE: 0.172965; Opt. RMSE: 0.365648; Net. RMSE: 0.428892
# Batch #290; filtering RMSE: 0.242;Frac. RMSE: 0.140915; Opt. RMSE: 0.369420; Net. RMSE: 0.421477
# Batch #295; filtering RMSE: 0.237;Frac. RMSE: 0.119950; Opt. RMSE: 0.365296; Net. RMSE: 0.409113
# Batch #300; filtering RMSE: 0.242;Frac. RMSE: 0.121249; Opt. RMSE: 0.370638; Net. RMSE: 0.415577
# Batch #305; filtering RMSE: 0.237;Frac. RMSE: 0.143227; Opt. RMSE: 0.368602; Net. RMSE: 0.421396
# Batch #310; filtering RMSE: 0.234;Frac. RMSE: 0.141922; Opt. RMSE: 0.372734; Net. RMSE: 0.425633
# Batch #315; filtering RMSE: 0.227;Frac. RMSE: 0.095378; Opt. RMSE: 0.368958; Net. RMSE: 0.404149
# Batch #320; filtering RMSE: 0.227;Frac. RMSE: 0.092189; Opt. RMSE: 0.373687; Net. RMSE: 0.408137
# Batch #325; filtering RMSE: 0.227;Frac. RMSE: 0.118365; Opt. RMSE: 0.369705; Net. RMSE: 0.413465
# Batch #330; filtering RMSE: 0.235;Frac. RMSE: 0.123528; Opt. RMSE: 0.369263; Net. RMSE: 0.414877
# Batch #335; filtering RMSE: 0.231;Frac. RMSE: 0.142358; Opt. RMSE: 0.369662; Net. RMSE: 0.422287
# Batch #340; filtering RMSE: 0.214;Frac. RMSE: 0.090569; Opt. RMSE: 0.369503; Net. RMSE: 0.402969
# Batch #345; filtering RMSE: 0.212;Frac. RMSE: 0.102370; Opt. RMSE: 0.369426; Net. RMSE: 0.407244
# Batch #350; filtering RMSE: 0.226;Frac. RMSE: 0.117785; Opt. RMSE: 0.370641; Net. RMSE: 0.414296
# Batch #355; filtering RMSE: 0.209;Frac. RMSE: 0.097223; Opt. RMSE: 0.372774; Net. RMSE: 0.409016
# Batch #360; filtering RMSE: 0.208;Frac. RMSE: 0.084263; Opt. RMSE: 0.370193; Net. RMSE: 0.401387
# Batch #365; filtering RMSE: 0.212;Frac. RMSE: 0.104652; Opt. RMSE: 0.370678; Net. RMSE: 0.409470
# Batch #370; filtering RMSE: 0.210;Frac. RMSE: 0.099905; Opt. RMSE: 0.369183; Net. RMSE: 0.406066
# Batch #375; filtering RMSE: 0.217;Frac. RMSE: 0.116391; Opt. RMSE: 0.369838; Net. RMSE: 0.412884
# Batch #380; filtering RMSE: 0.203;Frac. RMSE: 0.099865; Opt. RMSE: 0.368103; Net. RMSE: 0.404863
# Batch #385; filtering RMSE: 0.213;Frac. RMSE: 0.095174; Opt. RMSE: 0.373796; Net. RMSE: 0.409372
# Batch #390; filtering RMSE: 0.212;Frac. RMSE: 0.096338; Opt. RMSE: 0.370087; Net. RMSE: 0.405740
# Batch #395; filtering RMSE: 0.209;Frac. RMSE: 0.103567; Opt. RMSE: 0.371806; Net. RMSE: 0.410312
# Batch #400; filtering RMSE: 0.204;Frac. RMSE: 0.096858; Opt. RMSE: 0.370480; Net. RMSE: 0.406364
# Batch #405; filtering RMSE: 0.199;Frac. RMSE: 0.090449; Opt. RMSE: 0.372943; Net. RMSE: 0.406675
# Batch #410; filtering RMSE: 0.194;Frac. RMSE: 0.063399; Opt. RMSE: 0.374852; Net. RMSE: 0.398617
# Batch #415; filtering RMSE: 0.182;Frac. RMSE: 0.083208; Opt. RMSE: 0.370885; Net. RMSE: 0.401746
# Batch #420; filtering RMSE: 0.192;Frac. RMSE: 0.076066; Opt. RMSE: 0.370957; Net. RMSE: 0.399174
# Batch #425; filtering RMSE: 0.198;Frac. RMSE: 0.102582; Opt. RMSE: 0.369959; Net. RMSE: 0.407910
# Batch #430; filtering RMSE: 0.195;Frac. RMSE: 0.082113; Opt. RMSE: 0.369988; Net. RMSE: 0.400369
# Batch #435; filtering RMSE: 0.186;Frac. RMSE: 0.054086; Opt. RMSE: 0.369680; Net. RMSE: 0.389674
# Batch #440; filtering RMSE: 0.186;Frac. RMSE: 0.077302; Opt. RMSE: 0.367532; Net. RMSE: 0.395944
# Batch #445; filtering RMSE: 0.178;Frac. RMSE: 0.074244; Opt. RMSE: 0.368213; Net. RMSE: 0.395550
# Batch #450; filtering RMSE: 0.191;Frac. RMSE: 0.091378; Opt. RMSE: 0.370974; Net. RMSE: 0.404873
# Batch #455; filtering RMSE: 0.186;Frac. RMSE: 0.080781; Opt. RMSE: 0.365324; Net. RMSE: 0.394835
# Batch #460; filtering RMSE: 0.196;Frac. RMSE: 0.092424; Opt. RMSE: 0.366924; Net. RMSE: 0.400837
# Batch #465; filtering RMSE: 0.200;Frac. RMSE: 0.082401; Opt. RMSE: 0.371301; Net. RMSE: 0.401896
# Batch #470; filtering RMSE: 0.191;Frac. RMSE: 0.085088; Opt. RMSE: 0.371063; Net. RMSE: 0.402636
# Batch #475; filtering RMSE: 0.181;Frac. RMSE: 0.072411; Opt. RMSE: 0.372298; Net. RMSE: 0.399256
# Batch #480; filtering RMSE: 0.179;Frac. RMSE: 0.078628; Opt. RMSE: 0.368129; Net. RMSE: 0.397074
# Batch #485; filtering RMSE: 0.176;Frac. RMSE: 0.050804; Opt. RMSE: 0.370881; Net. RMSE: 0.389723
# Batch #490; filtering RMSE: 0.174;Frac. RMSE: 0.079740; Opt. RMSE: 0.366570; Net. RMSE: 0.395800
# Batch #495; filtering RMSE: 0.176;Frac. RMSE: 0.076196; Opt. RMSE: 0.369113; Net. RMSE: 0.397238
# Batch #500; filtering RMSE: 0.168;Frac. RMSE: 0.038808; Opt. RMSE: 0.369452; Net. RMSE: 0.383790

# %%
plt.plot(mse_losses)
plt.yscale("log")

# %%
trial = 80
t_len = len(output_dict['readout_output'][trial,:,-1])
n_neurons = output_dict['core_output'][trial].shape[0]
fig,ax = plt.subplots(2,1)
# ax[0].plot(np.exp(output_dict['readout_output'][trial,:,-1].detach().numpy()),label = "Network output")
# ax[0].plot(np.exp(opt_s[trial,:,-1]),label = "PPSSM Filtering")
ax[0].plot(output_dict['readout_output'][trial,:,-1].detach().numpy(),label = "Network output")
ax[0].plot(opt_s[trial,:,-1],label = "PPSSM Filtering")
ax[0].plot(example_output[trial,:,-1],label = 'Reward Sequence')
ax[0].legend()

# ax[1].imshow(np.flipud(example_input[trial].detach().numpy().T))
peaksort_vis_trial(output_dict['core_output'][trial],ax = ax[1],sort_end_ix = 20)
aspect = 3.5 * t_len/n_neurons
forceAspect(ax[1],aspect)
# forceAspect(ax[0],aspect)

# %%
n_batches = 1
test_task = PPSSM_FilteringTask(rxx_ppssm_params,max_iter = n_batches)
model.batch_size = test_task.batch_size

# %%
# Run model on test trials 
s_vec, opt_s_vec, ex_pred_vec, frac_rmse_vec = [], [], [], []
for i, (example_input, example_output, opt_s) in test_task: # loop over batches in training set 
    optimizer.zero_grad() # zero the gradients
    output_dict = model.forward(example_input) # perform forward pass

# %%
trial = 0
t_len = len(output_dict['readout_output'][trial,:,-1])
n_neurons = output_dict['core_output'][trial].shape[0]
fig,ax = plt.subplots(2,1)
ax[0].plot(output_dict['readout_output'][trial,:,-1].detach().numpy(),label = "Network output")
ax[0].plot(opt_s[trial,:,-1],label = "PPSSM Filtering")
ax[0].plot(example_output[trial,:,-1],label = 'Reward Sequence')
ax[0].legend()

# ax[1].imshow(np.flipud(example_input[trial].detach().numpy().T))
peaksort_vis_trial(output_dict['core_output'][trial],ax = ax[1],sort_end_ix = 20)
aspect = 3.5 * t_len/n_neurons
forceAspect(ax[1],aspect)
# forceAspect(ax[0],aspect)

# %%
# visualize weight matrix?
w = model.core.weight_hh_l0.detach().numpy()
# np.fill_diagonal(w,0)
plt.imshow(w[np.any(w > 0,axis = 1) & np.any(w > 0,axis = 0)],cmap = 'RdBu')
plt.colorbar()

# %% [markdown]
# ### Running list of what is working
#
# - Linear output, train on 4XX --> good match to the rewards!
#     - No assumption of smoothness baked in! --> just jumps up and goes back down after reward is over
#     - A problem here is that the estimated rate can be negative
#
# - Linear output, train on 4XX --> reproduce opt_s
#
# - Elu causes training difficulties
#
# - Solutions: nll loss w/ CIF that actually follows a random walk?
#
# - Another thing to investigate is whether the Kalman filter can produce a p(greater signal)

# %% [markdown]
# ## Taking a step back
#
# add point process generating function with true underlying noise assumptions
#
# Weight on reward events could explain filtering w/ low $\sigma^2_{\epsilon}$

# %%
theta0 = 2 
sigma2_0 = .1
sigma2_eps = 0.05
end_t = 10
def srw_point_process(end_t,theta0,sigma2_eps,n_trials = 50,dt = 0.05): 
    n_tsteps = int(np.round(end_t / dt))
    theta = np.zeros((n_trials,n_tsteps))
    y = np.zeros((n_trials,n_tsteps)) 
    for i_trial in range(n_trials):
        theta[i_trial,0] = theta0 + rnd.normal(0,np.sqrt(sigma2_eps))
        for i in range(1,n_tsteps): 
            theta[i_trial,i] = theta[i_trial,i-1] + rnd.normal(0,np.sqrt(sigma2_eps)) 
            lam = np.exp(theta[i_trial,i])
            y[i_trial,i] = int(rnd.rand() < (lam * dt) * np.exp(-lam * dt))
    return y,theta

def ppssm_filtering(y,theta_0,sigma2_0,sigma2_eps,dt = 0.05): 
    """ 
        Calculate estimated rate lambda and its variance 
        From a binary sequence y according to PPSSM filtering equations
    """
    seq_len = len(y)
    theta = np.concatenate((np.array([theta_0],dtype = np.float64),np.array(np.zeros(seq_len-1,dtype = np.float64))))
    sigma2 = np.concatenate((np.array([sigma2_0],dtype = np.float64),np.array(np.zeros(seq_len-1,dtype = np.float64))))
    for t in range(1,seq_len): 
        sigma2_given_tminus1 = sigma2[t-1] + sigma2_eps
        sigma2[t] = np.min([10,(1 / (dt*np.exp(theta[t-1]) + 1/sigma2_given_tminus1))])
        theta[t] = theta[t-1] + sigma2[t] * (y[t] - dt*np.exp(theta[t-1]))
    return theta,sigma2

def pp_nll(theta,y,w = np.array([1,1]),dt = 0.05): 
    """ 
        Return point process NLL given discrete observation series y and estimated CIF lambda
    """
    w_vec = np.zeros(len(y))
    w_vec[y == 0] = w[0]
    w_vec[y == 1] = w[1]
    return -(w_vec * np.log((np.power(np.exp(theta) * dt,y) * np.exp(-np.exp(theta) * dt).T))).sum()

# %%
# this is the actual task we want to train the rnn to perform; only test on our foraging
# min nll sigma2_eps changes depending on weights on positive and negative events
end_t = 10
n_iter = 100
theta0 = 1.5
sigma2_eps = 0.05
dt = 0.05

fig,ax = plt.subplots(3,1,figsize =  (8,5))
w = np.array([1,2])
w_pos_range = np.linspace(0.5,10,15)
sigma2_eps_range = np.linspace(0.01,1.5,10)
cmap = sns.color_palette("coolwarm",len(sigma2_eps_range))
nll = np.zeros((len(sigma2_eps_range),len(w_pos_range),n_iter))
for this_iteration in range(n_iter):
    y,theta = gen_point_process(end_t,theta0,sigma2_eps,dt = dt)
    for i,sigma2_eps in enumerate(sigma2_eps_range):
        theta_est,_ = ppssm_filtering(y,theta0,sigma2_eps,0.001,dt = dt)
        if this_iteration == n_iter -1:
            ax[2].plot(np.exp(theta_est),label = r"$\sigma^2_{\epsilon} = %.3f$"%sigma2_eps,color = cmap[i])
        for i_w,w2 in enumerate(w_pos_range):
            nll[i,i_w,this_iteration] = pp_nll(theta_est,y,w = np.array([1,w2]))

nll = np.mean(nll,axis = 2)
nll = nll / np.sum(nll,axis = 0)[np.newaxis,:]
        
ax[0].plot(y)
ax[0].set_title("Events")
ax[1].plot(np.exp(theta))
ax[1].set_title(r"True $\lambda$")
ax[2].legend(loc = 1,bbox_to_anchor=(1.5,1.5))
ax[2].set_title(r"Estimated $\lambda$ from Filtering")
fig.tight_layout()

# %%
sns.heatmap(nll,yticklabels = sigma2_eps_range,xticklabels = w_pos_range,cmap = "magma")
plt.ylabel("Sigma2_eps" )
plt.xlabel("Weight on reward pos vs no reward")
# Out:
# Text(0.5, 15.0, 'Weight on reward pos vs no reward')

# %% [markdown]
# ## Back to RNN training
# - Optimize to perform filtering task using different weighting on getting reward events correct

# %%
def pp_nll_loss(theta,y,w = torch.tensor([1,1]),dt = 0.05,lam_clip = [1e-1,100]): 
    """ 
        Return point process NLL given discrete observation series y and estimated CIF lambda
        Apply weighting with w
    """
    y = y.double()
    w_vec = torch.zeros(y.shape,dtype = torch.double)
    w_vec[y == 0.] = w[0]
    w_vec[y == 1.] = w[1]
    lam =  torch.clamp(torch.torch.exp(theta) * dt,lam_clip[0],lam_clip[1])
    return -(w_vec * (-lam + y * torch.log(lam))).sum()

# %%
# Training setup
tr_cond = 'high_gain'
n_batches = 2000
task = PPSSM_FilteringTask(srw_ppssm_params,max_iter = n_batches)
model_kwargs['batch_size'] = task.batch_size
model = RecurrentModel(model_kwargs)

# Training parameters
activity_l2_penalty = 1e-4 
activity_penalty_steps = 5 # number of activity steps before trial end to penalize
param_l2_penalty = 1e-2 # (aka weight decay)
lr = 0.0005
grad_clip = 10
optimizer = optim.Adam(model.parameters(), lr = lr , weight_decay = param_l2_penalty)
training_w = torch.tensor([.1,10],dtype = torch.double)

# %%
# Issue: all of our gradients are 0!!

# %%
# TRAINING
s_vec, opt_s_vec, ex_pred_vec, frac_rmse_vec = [], [], [], []
for i, (example_input, example_output, opt_s) in task: # loop over batches in training set 
    optimizer.zero_grad() # zero the gradients
    output_dict = model.forward(example_input) # perform forward pass

    # calculate loss
    this_nll_loss = pp_nll_loss(output_dict['readout_output'][:,:,-1],example_output[:,:,-1],w = training_w)
    this_nll_loss.double().backward() # backpropagate gradients
    gradClamp(model.parameters(), clip = grad_clip) # clip gradients 
    optimizer.step() # perform optimization step

    total_losses[i] = loss.item() 
    mse_losses[i] = this_mse_loss.item()

    s_vec.append(example_output[:,:,-1].detach().numpy())
    opt_s_vec.append(opt_s[:,:,-1])
    ex_pred_vec.append(output_dict['readout_output'].detach().numpy()[:,:,-1])

    if i % 5 == 0:
        nll_opt = pp_nll_loss(torch.tensor(opt_s_vec),torch.tensor(s_vec), w = training_w)
        rmse_net  = pp_nll_loss(torch.tensor(ex_pred_vec),torch.tensor(s_vec), w = training_w)
        frac_rmse = (rmse_net - rmse_opt) / rmse_opt
        frac_rmse_vec.append(frac_rmse)
        print('Batch #%d; Frac. NLL: %.6f; Opt. NLL: %.6f; Net. NLL: %.6f' % (i, frac_rmse, rmse_opt, rmse_net))
        s_vec       = []
        opt_s_vec   = []
        ex_pred_vec = []
# Out:
# Batch #0; Frac. NLL: 7993.658863; Opt. NLL: 0.312916; Net. NLL: 2501.656775
# Batch #5; Frac. NLL: 31836.815504; Opt. NLL: 0.312916; Net. NLL: 9962.562285
# Batch #10; Frac. NLL: 36211.482977; Opt. NLL: 0.312916; Net. NLL: 11331.465788
# Batch #15; Frac. NLL: 34753.260486; Opt. NLL: 0.312916; Net. NLL: 10875.164620
# Batch #20; Frac. NLL: 34369.517725; Opt. NLL: 0.312916; Net. NLL: 10755.085366
# Batch #25; Frac. NLL: 37132.465603; Opt. NLL: 0.312916; Net. NLL: 11619.655999
# Batch #30; Frac. NLL: 32220.558265; Opt. NLL: 0.312916; Net. NLL: 10082.641540
# Batch #35; Frac. NLL: 32527.552474; Opt. NLL: 0.312916; Net. NLL: 10178.704943
# Batch #40; Frac. NLL: 33909.026412; Opt. NLL: 0.312916; Net. NLL: 10610.990260
# Batch #45; Frac. NLL: 36288.231529; Opt. NLL: 0.312916; Net. NLL: 11355.481639
# Batch #50; Frac. NLL: 38820.933750; Opt. NLL: 0.312916; Net. NLL: 12148.004720
# Batch #55; Frac. NLL: 33448.535099; Opt. NLL: 0.312916; Net. NLL: 10466.895155
# Batch #60; Frac. NLL: 32988.043787; Opt. NLL: 0.312916; Net. NLL: 10322.800049
# Batch #65; Frac. NLL: 35674.243112; Opt. NLL: 0.312916; Net. NLL: 11163.354831
# Batch #70; Frac. NLL: 33832.277860; Opt. NLL: 0.312916; Net. NLL: 10586.974409
# Batch #75; Frac. NLL: 36288.231529; Opt. NLL: 0.312916; Net. NLL: 11355.481639
# Batch #80; Frac. NLL: 35060.254695; Opt. NLL: 0.312916; Net. NLL: 10971.228024
# Batch #85; Frac. NLL: 34599.763382; Opt. NLL: 0.312916; Net. NLL: 10827.132918
# Batch #90; Frac. NLL: 35060.254695; Opt. NLL: 0.312916; Net. NLL: 10971.228024
# Batch #95; Frac. NLL: 39051.179406; Opt. NLL: 0.312916; Net. NLL: 12220.052272
# Batch #100; Frac. NLL: 30839.084326; Opt. NLL: 0.312916; Net. NLL: 9650.356223
# Batch #105; Frac. NLL: 37132.465603; Opt. NLL: 0.312916; Net. NLL: 11619.655999
# Batch #110; Frac. NLL: 35213.751799; Opt. NLL: 0.312916; Net. NLL: 11019.259726
# Batch #115; Frac. NLL: 33909.026412; Opt. NLL: 0.312916; Net. NLL: 10610.990260
# Batch #120; Frac. NLL: 35137.003247; Opt. NLL: 0.312916; Net. NLL: 10995.243875
# Batch #125; Frac. NLL: 34446.266277; Opt. NLL: 0.312916; Net. NLL: 10779.101217
# Batch #130; Frac. NLL: 35904.488768; Opt. NLL: 0.312916; Net. NLL: 11235.402384
# Batch #135; Frac. NLL: 32911.295234; Opt. NLL: 0.312916; Net. NLL: 10298.784198
# Batch #140; Frac. NLL: 35290.500351; Opt. NLL: 0.312916; Net. NLL: 11043.275577
# Batch #145; Frac. NLL: 33909.026412; Opt. NLL: 0.312916; Net. NLL: 10610.990260
# Batch #150; Frac. NLL: 33064.792339; Opt. NLL: 0.312916; Net. NLL: 10346.815900
# Batch #155; Frac. NLL: 34292.769173; Opt. NLL: 0.312916; Net. NLL: 10731.069515
# Batch #160; Frac. NLL: 33755.529308; Opt. NLL: 0.312916; Net. NLL: 10562.958558
# Batch #165; Frac. NLL: 34676.511934; Opt. NLL: 0.312916; Net. NLL: 10851.148769
# Batch #170; Frac. NLL: 29994.850253; Opt. NLL: 0.312916; Net. NLL: 9386.181863
# Batch #175; Frac. NLL: 33678.780756; Opt. NLL: 0.312916; Net. NLL: 10538.942707
# Batch #180; Frac. NLL: 34216.020621; Opt. NLL: 0.312916; Net. NLL: 10707.053664
# Batch #185; Frac. NLL: 36211.482977; Opt. NLL: 0.312916; Net. NLL: 11331.465788
# Batch #190; Frac. NLL: 34599.763382; Opt. NLL: 0.312916; Net. NLL: 10827.132918
# Batch #195; Frac. NLL: 32067.061161; Opt. NLL: 0.312916; Net. NLL: 10034.609838
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1596-ff8976152538> in <module>
#      11     optimizer.step() # perform optimization step
#      12
# ---> 13     total_losses[i] = loss.item()
#      14     mse_losses[i] = this_mse_loss.item()
#      15
#
# IndexError: index 200 is out of bounds for axis 0 with size 200

# %%
trial = 80
t_len = len(output_dict['readout_output'][trial,:,-1])
n_neurons = output_dict['core_output'][trial].shape[0]
fig,ax = plt.subplots(2,1)
ax[0].plot(output_dict['readout_output'][trial,:,-1].detach().numpy(),label = "Network output")
ax[0].plot(opt_s[trial,:,-1],label = "PPSSM Filtering")
ax[0].plot(example_output[trial,:,-1],label = 'Reward Sequence')
ax[0].legend()

# ax[1].imshow(np.flipud(example_input[trial].detach().numpy().T))
peaksort_vis_trial(output_dict['core_output'][trial],ax = ax[1],sort_end_ix = 20)
aspect = 3.5 * t_len/n_neurons
forceAspect(ax[1],aspect)

# %%
plt.hist(model.readout.weight.detach().numpy().flatten())
# Out:
# (array([  2.,  16.,  40.,  70., 112., 107.,  82.,  47.,  18.,   6.]),
#  array([-0.17912348, -0.14318992, -0.10725635, -0.07132278, -0.03538922,
#          0.00054435,  0.03647792,  0.07241149,  0.10834505,  0.14427862,
#          0.18021219]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(model.core.weight_hh_l0.detach().numpy().flatten())
# Out:
# (array([2.495e+05, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+01, 4.700e+02]),
#  array([-0.00300773,  0.09549726,  0.19400224,  0.29250722,  0.39101221,
#          0.48951719,  0.58802217,  0.68652716,  0.78503214,  0.88353712,
#          0.98204211]),
#  <a list of 10 Patch objects>)

# %%
fig,ax = plt.subplots(2,1)
ax[0].imshow((torch.pow(torch.exp(theta) * dt,y) * torch.exp(-torch.exp(theta) * dt)).detach().numpy())

ax[1].imshow(y.detach().numpy())
